# %%
import wandb
import os
import yaml

api = wandb.Api()

saves_dir = os.path.join(os.getcwd(), "experiments")
os.makedirs(saves_dir, exist_ok=True)

user = "alberto-abbo-84-bitstrapped"
project = "ddp-obj-det-v1"

runs = api.runs(f"{user}/{project}")

run_names = [run.name for run in runs]
run_ids = [run.id for run in runs]
for run in runs:
    # Run name and ID
    print(run.name, run.id)
# Out:
# wandb: [wandb.Api()] Loaded credentials for https://api.wandb.ai from /Users/albertomarengo/.netrc.
# jumping-smoke-1 frn505mq
# drawn-fire-2 a66oh5ip
# pious-glade-3 nzxhrewe
# peach-snow-7 dst37qpl
# colorful-surf-8 c96ezyb8
# hopeful-brook-9 winl4dcz
# confused-wood-10 hdxqzsty
# peach-shape-11 gataushz
# vague-night-12 bnxrsg3n
# divine-glitter-13 pos5p1s4
# splendid-star-14 5xf55vrv
# fallen-thunder-15 erm5bj5s
# laced-glade-16 mwb392ij
# exalted-elevator-17 dbww9kw5
# laced-star-18 fx9r9uiz
# dark-firefly-19 qrlsbxik
# flowing-wave-21 rekg7s3a
# lyric-aardvark-22 q8l6zys5
# winter-puddle-23 mpoq9ds6

# %%
run_index = -1
run_name = run_names[run_index]
latest_run = api.run(f"{user}/{project}/{run_ids[run_index]}")

# %%
latest_run.config
# Out:
# {'loss': {'box_loss': 'ciou',
#   'cls_loss': 'focal',
#   'obj_loss': 'focal',
#   'lambda_cls': 0,
#   'lambda_obj': 1,
#   'focal_alpha': 0.25,
#   'focal_gamma': 2,
#   'lambda_bbox': 7,
#   'apply_negative_mining': True},
#  'model': {'name': 'yolo',
#   'metadata': {'best_model_folder': 'trained_model'},
#   'image_size': [512, 512, 3],
#   'fpn_channels': 384,
#   'backbone_name': 'resnet34',
#   'nms_threshold': 0.55,
#   'max_detections': 100,
#   'train_backbone': True,
#   'returned_layers': [1, 2, 3, 4],
#   'score_threshold': 0.05},
#  'metric': 'torch_mAP',
#  'dataset': {'nc': 1,
#   'val': '../Dataset/validation/Vehicle registration plate',
#   'names': ['Reg-plate'],
#   'train': '../Dataset/train/Vehicle registration plate',
#   'metadata': {'url': 'https://www.dropbox.com/s/k81ljpmzy3fgtx9/Dataset.zip?dl=1',
#    'dataset': 'licence-plate-detection',
#    'project': 'licence-plate-detection',
#    'version': 1,
#    'workspace': 'alberto-marengo'}},
#  'project': {'name': 'ddp-obj-det-v1'},
#  'optimizer': {'lr': 0.0001,
#   'eps': 1e-08,
#   'name': 'adamw',
#   'beta_max': 0.999,
#   'beta_min': 0.9,
#   'momentum': 0.9,
#   'weight_decay': 0.0001},
#  'scheduler': {'name': 'cosine_warmup',
#   'min_lr_ratio': 0.01,
#   'warmup_epochs': 3},
#  'checkpoint': {'dir': 'checkpoints', 'version': 'version_0'},
#  'experiment': {'train': {'seed': 42,
#    'debug': False,
#    'epochs': 150,
#    'use_wandb': True,
#    'batch_size': 32,
#    'num_workers': 4}}}

# %%
history = latest_run.history()

# %%
history
# Out:
#      val_mar_small  val_map_large  val_map_per_class  _step  \
# 0         0.000568       0.002507           0.000127      0
# 1         0.004545       0.027751           0.000450      1
# 2         0.148295       0.026073           0.018864      2
# 3         0.075568       0.021254           0.006125      3
# 4         0.139205       0.002680           0.029365      4
# ..             ...            ...                ...    ...
# 146       0.448864       0.457574           0.439741    146
# 147       0.442045       0.442975           0.432920    147
# 148       0.450568       0.471980           0.442865    148
# 149       0.439773       0.428140           0.436917    149
# 150            NaN            NaN                NaN    150
#
#      val_mar_100_per_class  train_cls_loss  val_map_medium  val_mar_100  \
# 0                 0.033398             0.0        0.000417     0.033398
# 1                 0.091650             0.0        0.002252     0.091650
# 2                 0.143883             0.0        0.026811     0.143883
# 3                 0.138641             0.0        0.005117     0.138641
# 4                 0.133786             0.0        0.022952     0.133786
# ..                     ...             ...             ...          ...
# 146               0.593398             0.0        0.581697     0.593398
# 147               0.587961             0.0        0.574690     0.587961
# 148               0.594563             0.0        0.581810     0.594563
# 149               0.586796             0.0        0.577880     0.586796
# 150                    NaN             NaN             NaN          NaN
#
#      val_cls_loss     _runtime  ...  coco_eval_AP@0.50  coco_eval_AP_large  \
# 0             0.0    58.106861  ...                NaN                 NaN
# 1             0.0   115.901434  ...                NaN                 NaN
# 2             0.0   176.119685  ...                NaN                 NaN
# 3             0.0   237.700573  ...                NaN                 NaN
# 4             0.0   296.726767  ...                NaN                 NaN
# ..            ...          ...  ...                ...                 ...
# 146           0.0  8336.894391  ...                NaN                 NaN
# 147           0.0  8393.518170  ...                NaN                 NaN
# 148           0.0  8449.783859  ...                NaN                 NaN
# 149           0.0  8506.659569  ...                NaN                 NaN
# 150           NaN  8537.411175  ...           0.773017            0.428386
#
#      coco_eval_AP_medium  coco_eval_AR_max=100  coco_eval_AP@[.5:.95]  \
# 0                    NaN                   NaN                    NaN
# 1                    NaN                   NaN                    NaN
# 2                    NaN                   NaN                    NaN
# 3                    NaN                   NaN                    NaN
# 4                    NaN                   NaN                    NaN
# ..                   ...                   ...                    ...
# 146                  NaN                   NaN                    NaN
# 147                  NaN                   NaN                    NaN
# 148                  NaN                   NaN                    NaN
# 149                  NaN                   NaN                    NaN
# 150             0.577951              0.587305               0.436009
#
#      coco_eval_AR_large  coco_eval_AR_small  coco_eval_AP@0.75  \
# 0                   NaN                 NaN                NaN
# 1                   NaN                 NaN                NaN
# 2                   NaN                 NaN                NaN
# 3                   NaN                 NaN                NaN
# 4                   NaN                 NaN                NaN
# ..                  ...                 ...                ...
# 146                 NaN                 NaN                NaN
# 147                 NaN                 NaN                NaN
# 148                 NaN                 NaN                NaN
# 149                 NaN                 NaN                NaN
# 150            0.652778             0.43908           0.452632
#
#      coco_eval_AR_max=10  coco_eval_AP_small
# 0                    NaN                 NaN
# 1                    NaN                 NaN
# 2                    NaN                 NaN
# 3                    NaN                 NaN
# 4                    NaN                 NaN
# ..                   ...                 ...
# 146                  NaN                 NaN
# 147                  NaN                 NaN
# 148                  NaN                 NaN
# 149                  NaN                 NaN
# 150             0.577344            0.222551
#
# [151 rows x 40 columns]

# %%
# Save
os.makedirs(os.path.join(saves_dir, run_name), exist_ok=True)
history.to_csv(os.path.join(saves_dir, run_name, f"{run_name}_history.csv"), index=False)
config_dict = dict(latest_run.config)
with open(os.path.join(saves_dir, run_name, f"{run_name}_config.yaml"), "w") as file:
    yaml.dump(config_dict, file, default_flow_style=False)
