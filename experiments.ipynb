# %%
import wandb
import os
import yaml

api = wandb.Api()

saves_dir = os.path.join(os.getcwd(), "experiments")
os.makedirs(saves_dir, exist_ok=True)

user = "alberto-abbo-84-bitstrapped"
project = "ddp-obj-det-v1"

runs = api.runs(f"{user}/{project}")

run_names = [run.name for run in runs]
run_ids = [run.id for run in runs]
for run in runs:
    # Run name and ID
    print(run.name, run.id)
# Out:
# wandb: [wandb.Api()] Loaded credentials for https://api.wandb.ai from /Users/albertomarengo/.netrc.
# jumping-smoke-1 frn505mq
# drawn-fire-2 a66oh5ip
# pious-glade-3 nzxhrewe
# peach-snow-7 dst37qpl
# colorful-surf-8 c96ezyb8
# hopeful-brook-9 winl4dcz
# confused-wood-10 hdxqzsty
# peach-shape-11 gataushz
# vague-night-12 bnxrsg3n
# divine-glitter-13 pos5p1s4
# splendid-star-14 5xf55vrv
# fallen-thunder-15 erm5bj5s
# laced-glade-16 mwb392ij
# exalted-elevator-17 dbww9kw5
# laced-star-18 fx9r9uiz
# dark-firefly-19 qrlsbxik
# flowing-wave-21 rekg7s3a
# lyric-aardvark-22 q8l6zys5
# winter-puddle-23 mpoq9ds6
# unique-glitter-24 xnpcg43j
# treasured-dawn-25 4a0c1wma
# rural-firebrand-29 rpdqshvn
# pleasant-shape-30 9rulmoqv
# likely-sponge-31 9kzld9zd
# soft-firebrand-32 qyn0koqa
# fancy-universe-33 pkqpicbo

# %%
run_index = -1
run_name = run_names[run_index]
latest_run = api.run(f"{user}/{project}/{run_ids[run_index]}")

# %%
latest_run.config
# Out:
# {'loss': {'box_loss': 's1',
#   'cls_loss': 'focal',
#   'obj_loss': 'focal',
#   'lambda_cls': 0,
#   'lambda_obj': 2,
#   'focal_alpha': 0.25,
#   'focal_gamma': 2,
#   'lambda_bbox': 7,
#   'apply_negative_mining': True},
#  'model': {'name': 'yolo',
#   'metadata': {'best_model_folder': 'trained_model'},
#   'image_size': [512, 512, 3],
#   'fpn_channels': 384,
#   'backbone_name': 'resnet34',
#   'center_radius': 1,
#   'nms_threshold': 0.5,
#   'max_detections': 100,
#   'train_backbone': True,
#   'returned_layers': [1, 2, 3, 4],
#   'score_threshold': 0.01,
#   'top_k_per_level': 1,
#   'allow_multi_level': True},
#  'metric': 'torch_mAP',
#  'dataset': {'nc': 1,
#   'val': '../Dataset/validation/Vehicle registration plate',
#   'names': ['Reg-plate'],
#   'train': '../Dataset/train/Vehicle registration plate',
#   'metadata': {'url': 'https://www.dropbox.com/s/k81ljpmzy3fgtx9/Dataset.zip?dl=1',
#    'dataset': 'licence-plate-detection',
#    'project': 'licence-plate-detection',
#    'version': 1,
#    'workspace': 'alberto-marengo'}},
#  'project': {'name': 'ddp-obj-det-v1'},
#  'optimizer': {'lr': 0.0005,
#   'eps': 1e-08,
#   'name': 'adamw',
#   'beta_max': 0.999,
#   'beta_min': 0.9,
#   'momentum': 0.9,
#   'weight_decay': 0.0001},
#  'scheduler': {'name': 'cosine_warmup',
#   'min_lr_ratio': 0.01,
#   'warmup_epochs': 5},
#  'checkpoint': {'dir': 'checkpoints', 'version': 'version_0'},
#  'experiment': {'train': {'seed': 42,
#    'debug': False,
#    'epochs': 125,
#    'use_wandb': True,
#    'batch_size': 32,
#    'num_workers': 4}}}

# %%
history = latest_run.history()

# %%
history
# Out:
#      val_mar_small  val_map_large  val_map_per_class  _step  \
# 0         0.021591       0.072170           0.002467      0
# 1         0.123864       0.164509           0.091548      1
# 2         0.184091       0.304800           0.197475      2
# 3         0.178409       0.147800           0.189497      3
# 4         0.216477       0.003507           0.025358      4
# ..             ...            ...                ...    ...
# 118       0.467614       0.521159           0.505399    118
# 119       0.469318       0.563926           0.507935    119
# 120       0.463636       0.552868           0.506260    120
# 121       0.459659       0.566552           0.508260    121
# 122       0.466477       0.556666           0.507538    122
#
#      val_mar_100_per_class  train_cls_loss  val_map_medium  val_mar_100  \
# 0                 0.134175               0        0.005377     0.134175
# 1                 0.220194               0        0.130213     0.220194
# 2                 0.338058               0        0.288285     0.338058
# 3                 0.355728               0        0.363597     0.355728
# 4                 0.228932               0        0.042016     0.228932
# ..                     ...             ...             ...          ...
# 118               0.607379               0        0.584885     0.607379
# 119               0.608932               0        0.584902     0.608932
# 120               0.605049               0        0.583719     0.605049
# 121               0.603689               0        0.586331     0.603689
# 122               0.606214               0        0.584720     0.606214
#
#      val_cls_loss      _runtime  ...  val_total_loss  val_obj_loss  \
# 0               0    116.694156  ...        0.768741      0.205424
# 1               0    231.286817  ...        0.512157      0.112240
# 2               0    346.249197  ...        0.410980      0.088631
# 3               0    461.507604  ...        0.456484      0.077577
# 4               0    574.384392  ...        0.621236      0.077703
# ..            ...           ...  ...             ...           ...
# 118             0  13493.753342  ...        0.146525      0.039408
# 119             0  13606.414187  ...        0.146689      0.039251
# 120             0  13717.786144  ...        0.146908      0.040107
# 121             0  13829.815056  ...        0.146336      0.039756
# 122             0  13941.838991  ...        0.148898      0.040484
#
#      val_mar_10  val_mar_1  val_map_75  val_map_small    _timestamp  \
# 0      0.090291   0.022136    0.000099       0.000062  1.778938e+09
# 1      0.186408   0.118835    0.014258       0.006603  1.778938e+09
# 2      0.310485   0.239612    0.083986       0.022884  1.778938e+09
# 3      0.336505   0.248738    0.075180       0.026434  1.778938e+09
# 4      0.150680   0.068544    0.001273       0.055268  1.778938e+09
# ..          ...        ...         ...            ...           ...
# 118    0.593786   0.486602    0.523045       0.357095  1.778951e+09
# 119    0.595728   0.488155    0.529499       0.356950  1.778951e+09
# 120    0.591845   0.485243    0.523181       0.354445  1.778952e+09
# 121    0.593204   0.485243    0.528003       0.351234  1.778952e+09
# 122    0.593981   0.485437    0.526583       0.355290  1.778952e+09
#
#      val_mar_large  val_loc_loss  train_total_loss
# 0         0.211111      0.051128          1.414909
# 1         0.211111      0.041097          0.818961
# 2         0.380556      0.033388          0.736672
# 3         0.369444      0.043047          0.618398
# 4         0.088889      0.066547          0.621613
# ..             ...           ...               ...
# 118       0.691667      0.009673          0.129006
# 119       0.705556      0.009741          0.135691
# 120       0.700000      0.009528          0.128285
# 121       0.700000      0.009546          0.129889
# 122       0.700000      0.009704          0.127973
#
# [123 rows x 28 columns]

# %%
# Save
os.makedirs(os.path.join(saves_dir, run_name), exist_ok=True)
history.to_csv(os.path.join(saves_dir, run_name, f"{run_name}_history.csv"), index=False)
config_dict = dict(latest_run.config)
with open(os.path.join(saves_dir, run_name, f"{run_name}_config.yaml"), "w") as file:
    yaml.dump(config_dict, file, default_flow_style=False)
