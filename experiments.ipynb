# %%
import wandb
import os
import yaml

api = wandb.Api()

saves_dir = os.path.join(os.getcwd(), "experiments")
os.makedirs(saves_dir, exist_ok=True)

user = "alberto-abbo-84-bitstrapped"
project = "ddp-obj-det-v1"

runs = api.runs(f"{user}/{project}")

run_names = [run.name for run in runs]
run_ids = [run.id for run in runs]
for run in runs:
    # Run name and ID
    print(run.name, run.id)
# Out:
# jumping-smoke-1 frn505mq
# drawn-fire-2 a66oh5ip
# pious-glade-3 nzxhrewe
# peach-snow-7 dst37qpl
# colorful-surf-8 c96ezyb8
# hopeful-brook-9 winl4dcz
# confused-wood-10 hdxqzsty
# peach-shape-11 gataushz
# vague-night-12 bnxrsg3n
# divine-glitter-13 pos5p1s4
# splendid-star-14 5xf55vrv
# fallen-thunder-15 erm5bj5s
# laced-glade-16 mwb392ij
# exalted-elevator-17 dbww9kw5
# laced-star-18 fx9r9uiz
# dark-firefly-19 qrlsbxik
# flowing-wave-21 rekg7s3a
# lyric-aardvark-22 q8l6zys5
# winter-puddle-23 mpoq9ds6
# unique-glitter-24 xnpcg43j
# treasured-dawn-25 4a0c1wma
# rural-firebrand-29 rpdqshvn
# pleasant-shape-30 9rulmoqv
# likely-sponge-31 9kzld9zd
# soft-firebrand-32 qyn0koqa
# fancy-universe-33 pkqpicbo
# deep-smoke-34 mvu077zy
# solar-field-35 fz0gzbro
# soft-dust-36 rnw145r6
# curious-sound-37 7d96f0hw
# dulcet-rain-38 6n1mfbyh
# giddy-bush-39 dw93k5tu
# fancy-energy-40 nayl7mxy
# effortless-feather-41 2tuwxrxx
# sunny-haze-42 akschvwg
# feasible-oath-43 5rf0rzwd
# sunny-galaxy-44 phd10uqu
# efficient-butterfly-45 c0yqlj0u
# deft-mountain-46 v2dyy48s
# crimson-sunset-47 zj0fwlsp
# brisk-plant-48 jd735jut
# rare-donkey-49 uvn1fj0s
# devout-salad-50 i4gteqtg
# fresh-bird-51 kkx4s8qk
# scarlet-music-52 euh0hjgk
# stilted-snowball-53 gnokq4hm
# upbeat-tree-54 rq76u73v

# %%
run_index = -1
run_name = run_names[run_index]
latest_run = api.run(f"{user}/{project}/{run_ids[run_index]}")

# %%
latest_run.config
# Out:
# {'loss': {'s1_beta': 0.5,
#   'box_loss': 'hybrid_s1_diou',
#   'cls_loss': 'focal',
#   'obj_loss': 'focal',
#   'lambda_cls': 0,
#   'lambda_obj': 1.5,
#   'focal_alpha': 0.25,
#   'focal_gamma': 2,
#   'lambda_bbox': 8,
#   's1_reduction': 'custom_stride_weighted',
#   'stride_weight': {'max': 3, 'min': 0.75, 'base': 16},
#   'obj_neg_weight': 1.5,
#   'hybrid_xiou_weight': 0.5,
#   'apply_negative_mining': True},
#  'model': {'name': 'yolo',
#   'metadata': {'best_model_folder': 'trained_model'},
#   'image_size': [640, 640, 3],
#   'fpn_channels': 384,
#   'backbone_name': 'resnet50',
#   'center_radius': 1,
#   'nms_threshold': 0.5,
#   'attention_type': 'ResidualCBAM',
#   'max_detections': 100,
#   'train_backbone': True,
#   'returned_layers': [1, 2, 3, 4],
#   'score_threshold': 0.01,
#   'top_k_per_level': 2,
#   'allow_multi_level': True},
#  'metric': 'torch_mAP',
#  'dataset': {'nc': 1,
#   'val': '../Dataset/validation/Vehicle registration plate',
#   'names': ['Reg-plate'],
#   'train': '../Dataset/train/Vehicle registration plate',
#   'metadata': {'url': 'https://www.dropbox.com/s/k81ljpmzy3fgtx9/Dataset.zip?dl=1',
#    'dataset': 'licence-plate-detection',
#    'project': 'licence-plate-detection',
#    'version': 1,
#    'workspace': 'alberto-marengo'}},
#  'project': {'name': 'ddp-obj-det-v1'},
#  'optimizer': {'lr': 0.0005,
#   'eps': 1e-08,
#   'name': 'adamw',
#   'beta_max': 0.999,
#   'beta_min': 0.9,
#   'momentum': 0.9,
#   'weight_decay': 0.0001},
#  'scheduler': {'name': 'cosine_warmup',
#   'min_lr_ratio': 0.01,
#   'warmup_epochs': 5},
#  'checkpoint': {'dir': 'checkpoints', 'version': 'version_0'},
#  'experiment': {'train': {'seed': 42,
#    'debug': False,
#    'epochs': 250,
#    'use_wandb': True,
#    'batch_size': 32,
#    'num_workers': 4}}}

# %%
history = latest_run.history()

# %%
history
# Out:
#      _step  train_obj_loss  val_mar_medium  train_cls_loss  coco_eval_AP@0.75  \
# 0        0        0.240501        0.001115             0.0                NaN
# 1        1        0.232917        0.009294             0.0                NaN
# 2        2        0.217274        0.395539             0.0                NaN
# 3        3        0.207005        0.314870             0.0                NaN
# 4        4        0.202188        0.485874             0.0                NaN
# ..     ...             ...             ...             ...                ...
# 246    246        0.028353        0.742007             0.0                NaN
# 247    247        0.029286        0.745353             0.0                NaN
# 248    248        0.029774        0.742379             0.0                NaN
# 249    249        0.029207        0.742007             0.0                NaN
# 250    250             NaN             NaN             NaN           0.642365
#
#      val_mar_100_per_class  val_loc_loss  coco_eval_AP@[.5:.95]      _runtime  \
# 0                 0.001359      0.953651                    NaN     52.456172
# 1                 0.006796      0.792962                    NaN    103.566116
# 2                 0.272816      0.656104                    NaN    154.982664
# 3                 0.237864      0.626009                    NaN    206.376829
# 4                 0.333786      0.713921                    NaN    256.113098
# ..                     ...           ...                    ...           ...
# 246               0.659223      0.186472                    NaN  12133.371066
# 247               0.661942      0.186721                    NaN  12182.085542
# 248               0.658447      0.186881                    NaN  12230.968998
# 249               0.655922      0.187851                    NaN  12280.028296
# 250                    NaN           NaN                0.56216  12331.869551
#
#      val_map_50  ...  val_mar_small  coco_eval_AP@0.50  coco_eval_AP_medium  \
# 0      0.000001  ...       0.002581                NaN                  NaN
# 1      0.000021  ...       0.006452                NaN                  NaN
# 2      0.470817  ...       0.016774                NaN                  NaN
# 3      0.383645  ...       0.045806                NaN                  NaN
# 4      0.477539  ...       0.060000                NaN                  NaN
# ..          ...  ...            ...                ...                  ...
# 246    0.893601  ...       0.501935                NaN                  NaN
# 247    0.893642  ...       0.508387                NaN                  NaN
# 248    0.895465  ...       0.501935                NaN                  NaN
# 249    0.892808  ...       0.496129                NaN                  NaN
# 250         NaN  ...            NaN           0.891389             0.672759
#
#      coco_eval_AP_large  val_total_loss  val_map_large  coco_eval_AR_small  \
# 0                   NaN        7.988096       0.000000                 NaN
# 1                   NaN        6.682793       0.000000                 NaN
# 2                   NaN        5.548750       0.269787                 NaN
# 3                   NaN        5.285458       0.204626                 NaN
# 4                   NaN        5.961212       0.223869                 NaN
# ..                  ...             ...            ...                 ...
# 246                 NaN        1.532816       0.612553                 NaN
# 247                 NaN        1.534688       0.603936                 NaN
# 248                 NaN        1.536347       0.604463                 NaN
# 249                 NaN        1.544384       0.598715                 NaN
# 250            0.599922             NaN            NaN            0.497386
#
#      train_loc_loss  val_map_75  val_map_medium
# 0          1.435218    0.000000    1.092945e-07
# 1          0.967338    0.000001    7.735350e-06
# 2          0.926231    0.071008    2.364176e-01
# 3          0.942129    0.011569    1.304246e-01
# 4          0.956256    0.100767    2.974424e-01
# ..              ...         ...             ...
# 246        0.188760    0.653848    6.719749e-01
# 247        0.188796    0.648643    6.759936e-01
# 248        0.193173    0.657976    6.746359e-01
# 249        0.194894    0.644383    6.717197e-01
# 250             NaN         NaN             NaN
#
# [251 rows x 40 columns]

# %%
# Save
os.makedirs(os.path.join(saves_dir, run_name), exist_ok=True)
history.to_csv(os.path.join(saves_dir, run_name, f"{run_name}_history.csv"), index=False)
config_dict = dict(latest_run.config)
with open(os.path.join(saves_dir, run_name, f"{run_name}_config.yaml"), "w") as file:
    yaml.dump(config_dict, file, default_flow_style=False)
