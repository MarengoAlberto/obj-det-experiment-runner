# %%
import wandb
import os
import yaml

api = wandb.Api()

saves_dir = os.path.join(os.getcwd(), "experiments")
os.makedirs(saves_dir, exist_ok=True)

user = "alberto-abbo-84-bitstrapped"
project = "ddp-obj-det-v1"

runs = api.runs(f"{user}/{project}")

run_names = [run.name for run in runs]
run_ids = [run.id for run in runs]
for run in runs:
    # Run name and ID
    print(run.name, run.id)
# Out:
# wandb: [wandb.Api()] Loaded credentials for https://api.wandb.ai from /Users/albertomarengo/.netrc.
# jumping-smoke-1 frn505mq
# drawn-fire-2 a66oh5ip
# pious-glade-3 nzxhrewe
# peach-snow-7 dst37qpl
# colorful-surf-8 c96ezyb8
# hopeful-brook-9 winl4dcz
# confused-wood-10 hdxqzsty
# peach-shape-11 gataushz
# vague-night-12 bnxrsg3n
# divine-glitter-13 pos5p1s4
# splendid-star-14 5xf55vrv
# fallen-thunder-15 erm5bj5s
# laced-glade-16 mwb392ij
# exalted-elevator-17 dbww9kw5
# laced-star-18 fx9r9uiz
# dark-firefly-19 qrlsbxik
# flowing-wave-21 rekg7s3a
# lyric-aardvark-22 q8l6zys5
# winter-puddle-23 mpoq9ds6
# unique-glitter-24 xnpcg43j
# treasured-dawn-25 4a0c1wma
# rural-firebrand-29 rpdqshvn
# pleasant-shape-30 9rulmoqv
# likely-sponge-31 9kzld9zd
# soft-firebrand-32 qyn0koqa
# fancy-universe-33 pkqpicbo
# deep-smoke-34 mvu077zy
# solar-field-35 fz0gzbro
# soft-dust-36 rnw145r6
# curious-sound-37 7d96f0hw
# dulcet-rain-38 6n1mfbyh
# giddy-bush-39 dw93k5tu
# fancy-energy-40 nayl7mxy
# effortless-feather-41 2tuwxrxx
# sunny-haze-42 akschvwg
# feasible-oath-43 5rf0rzwd
# sunny-galaxy-44 phd10uqu
# efficient-butterfly-45 c0yqlj0u
# deft-mountain-46 v2dyy48s
# crimson-sunset-47 zj0fwlsp
# brisk-plant-48 jd735jut
# rare-donkey-49 uvn1fj0s
# devout-salad-50 i4gteqtg
# fresh-bird-51 kkx4s8qk
# scarlet-music-52 euh0hjgk
# stilted-snowball-53 gnokq4hm
# upbeat-tree-54 rq76u73v
# jumping-plasma-55 2nucsm3c

# %%
run_index = -1
run_name = run_names[run_index]
latest_run = api.run(f"{user}/{project}/{run_ids[run_index]}")

# %%
latest_run.config
# Out:
# {'loss': {'s1_beta': 0.5,
#   'box_loss': 'hybrid_s1_ciou',
#   'cls_loss': 'focal',
#   'obj_loss': 'focal',
#   'lambda_cls': 0,
#   'lambda_obj': 1.5,
#   'focal_alpha': 0.25,
#   'focal_gamma': 2,
#   'lambda_bbox': 8,
#   's1_reduction': 'custom_stride_weighted',
#   'stride_weight': {'max': 3.25, 'min': 1, 'base': 18},
#   'obj_neg_weight': 1.5,
#   'hybrid_xiou_weight': 0.75,
#   'apply_negative_mining': True},
#  'model': {'name': 'yolo',
#   'metadata': {'best_model_folder': 'trained_model'},
#   'image_size': [640, 640, 3],
#   'fpn_channels': 384,
#   'backbone_name': 'resnet50',
#   'center_radius': 1,
#   'nms_threshold': 0.5,
#   'attention_type': 'ResidualCBAM',
#   'max_detections': 100,
#   'train_backbone': True,
#   'returned_layers': [1, 2, 3, 4],
#   'score_threshold': 0.01,
#   'top_k_per_level': 2,
#   'allow_multi_level': True},
#  'metric': 'torch_mAP',
#  'dataset': {'nc': 1,
#   'val': '../Dataset/validation/Vehicle registration plate',
#   'names': ['Reg-plate'],
#   'train': '../Dataset/train/Vehicle registration plate',
#   'metadata': {'url': 'https://www.dropbox.com/s/k81ljpmzy3fgtx9/Dataset.zip?dl=1',
#    'dataset': 'licence-plate-detection',
#    'project': 'licence-plate-detection',
#    'version': 1,
#    'workspace': 'alberto-marengo'}},
#  'project': {'name': 'ddp-obj-det-v1'},
#  'optimizer': {'lr': 0.0005,
#   'eps': 1e-08,
#   'name': 'adamw',
#   'beta_max': 0.999,
#   'beta_min': 0.9,
#   'momentum': 0.9,
#   'weight_decay': 0.0001},
#  'scheduler': {'name': 'cosine_warmup',
#   'min_lr_ratio': 0.01,
#   'warmup_epochs': 5},
#  'checkpoint': {'dir': 'checkpoints', 'version': 'version_0'},
#  'experiment': {'train': {'seed': 42,
#    'debug': False,
#    'epochs': 250,
#    'use_wandb': True,
#    'batch_size': 32,
#    'num_workers': 4}}}

# %%
history = latest_run.history()

# %%
history
# Out:
#      val_mar_small  val_map_large  val_map_per_class  _step  \
# 0         0.004516       0.000000           0.000001      0
# 1         0.005806       0.059686           0.058699      1
# 2         0.018710       0.108859           0.086389      2
# 3         0.067097       0.110418           0.098053      3
# 4         0.113548       0.294476           0.196180      4
# ..             ...            ...                ...    ...
# 246       0.502581       0.624412           0.572732    246
# 247       0.503871       0.624716           0.573354    247
# 248       0.500645       0.624764           0.575110    248
# 249       0.505806       0.622387           0.573981    249
# 250            NaN            NaN                NaN    250
#
#      val_mar_100_per_class  train_cls_loss  val_map_medium  val_mar_100  \
# 0                 0.001748             0.0    1.464752e-07     0.001748
# 1                 0.152816             0.0    9.377278e-02     0.152816
# 2                 0.201553             0.0    1.301035e-01     0.201553
# 3                 0.247184             0.0    1.487583e-01     0.247184
# 4                 0.326408             0.0    2.748657e-01     0.326408
# ..                     ...             ...             ...          ...
# 246               0.660971             0.0    6.729230e-01     0.660971
# 247               0.662524             0.0    6.757759e-01     0.662524
# 248               0.661748             0.0    6.769327e-01     0.661748
# 249               0.663107             0.0    6.743864e-01     0.663107
# 250                    NaN             NaN             NaN          NaN
#
#      val_cls_loss      _runtime  ...  coco_eval_AP@0.50  coco_eval_AP_large  \
# 0             0.0     51.307357  ...                NaN                 NaN
# 1             0.0    101.473172  ...                NaN                 NaN
# 2             0.0    152.793493  ...                NaN                 NaN
# 3             0.0    202.827358  ...                NaN                 NaN
# 4             0.0    253.022495  ...                NaN                 NaN
# ..            ...           ...  ...                ...                 ...
# 246           0.0  12317.738517  ...                NaN                 NaN
# 247           0.0  12366.765754  ...                NaN                 NaN
# 248           0.0  12416.243756  ...                NaN                 NaN
# 249           0.0  12465.366527  ...                NaN                 NaN
# 250           NaN  12518.107258  ...           0.894597            0.628217
#
#      coco_eval_AP_medium  coco_eval_AR_max=100  coco_eval_AP@[.5:.95]  \
# 0                    NaN                   NaN                    NaN
# 1                    NaN                   NaN                    NaN
# 2                    NaN                   NaN                    NaN
# 3                    NaN                   NaN                    NaN
# 4                    NaN                   NaN                    NaN
# ..                   ...                   ...                    ...
# 246                  NaN                   NaN                    NaN
# 247                  NaN                   NaN                    NaN
# 248                  NaN                   NaN                    NaN
# 249                  NaN                   NaN                    NaN
# 250             0.674723              0.662305               0.572617
#
#      coco_eval_AR_large  coco_eval_AR_small  coco_eval_AP@0.75  \
# 0                   NaN                 NaN                NaN
# 1                   NaN                 NaN                NaN
# 2                   NaN                 NaN                NaN
# 3                   NaN                 NaN                NaN
# 4                   NaN                 NaN                NaN
# ..                  ...                 ...                ...
# 246                 NaN                 NaN                NaN
# 247                 NaN                 NaN                NaN
# 248                 NaN                 NaN                NaN
# 249                 NaN                 NaN                NaN
# 250            0.696703            0.500654           0.632303
#
#      coco_eval_AR_max=10  coco_eval_AP_small
# 0                    NaN                 NaN
# 1                    NaN                 NaN
# 2                    NaN                 NaN
# 3                    NaN                 NaN
# 4                    NaN                 NaN
# ..                   ...                 ...
# 246                  NaN                 NaN
# 247                  NaN                 NaN
# 248                  NaN                 NaN
# 249                  NaN                 NaN
# 250             0.651758            0.334309
#
# [251 rows x 40 columns]

# %%
# Save
os.makedirs(os.path.join(saves_dir, run_name), exist_ok=True)
history.to_csv(os.path.join(saves_dir, run_name, f"{run_name}_history.csv"), index=False)
config_dict = dict(latest_run.config)
with open(os.path.join(saves_dir, run_name, f"{run_name}_config.yaml"), "w") as file:
    yaml.dump(config_dict, file, default_flow_style=False)
